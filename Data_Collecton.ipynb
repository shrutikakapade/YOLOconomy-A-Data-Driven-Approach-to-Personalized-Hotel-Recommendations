# %%
import requests as req
import numpy as np
import pandas as pd
import warnings
import re
warnings.filterwarnings("ignore")

# %%
url = "https://www.booking.com/searchresults.en-gb.html?label=msn-OtA8KVb8PL6q89f9dZV*9g-80814291883323%3Atikwd-80814466535357%3Aloc-90%3Aneo%3Amte%3Alp157592%3Adec%3Aqshttps%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaGyIAQGYATG4ARfIAQzYAQHoAQH4AQKIAgGoAgO4Ar-r478GwAIB0gIkMGI0ODM2NDEtMDQxNC00NGFlLWE5NzctNTE2YjM1NTczOWYw2AIF4AIB&aid=2369666&ss=New+Delhi&ssne=New+Delhi&ssne_untouched=New+Delhi&efdco=1&lang=en-gb&src=searchresults&dest_id=-2106102&dest_type=city&checkin=2025-07-04&checkout=2025-07-05&ltfd=1%3A5%3A7-2025_8-2025%3A1%3A&group_adults=10&no_rooms=5&group_children=0&flex_window=7&nflt=review_score%3D80%3Bclass%3D5%3Breview_score%3D90%3Bprivacy_type%3D3%3Bht_id%3D201%3Bht_id%3D213%3Bclass%3D4%3Bht_id%3D204%3Breview_score%3D70%3Bht_id%3D208"

# %%
req.get(url) #success
# Out:
# <Response [200]>

# %%
request_header = {'Content-Type': 'text/html; charset=UTF-8','User-Agent': 'Chrome/101.0.0.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0','Accept-Encoding': 'gzip, deflate, br'}

page = req.get(url,headers =request_header)

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<!--\nYou know you could be getting paid to poke around in our code?\nWe\'re hiring designers and developers to work in Amsterdam:\nhttps://careers.booking.com/\n-->\n<!-- wdot-802 -->\n<script type="text/javascript" nonce="BaCfueMAvbyqsGD">\ndocument.addEventListener(\'DOMContentLoaded\', function () {\n/**\n* provides the current user\'s cookie consent\n* in order to use it:\n* 1. inline privacy/cookieConsent.js in the page you need to use it.\n* please note that this library relies on window.PCM.isCountryNeedCookieBanner to be initialised\n* before using (calling getValue function) it\n* 2. in your js file:\n*\n* var privacyCookieConsent = B.require(\'privacyCookieConsent\');\n* var consent = privacyCookieConsent.getValue();\n*/\nB.define(\'privacyCookieConsent\', function () {\nvar consentGroupIsAllowed = {\nanalytical: \'C0002%3A1\',\nmarketing: \'C0004%3A1\'\n};\nvar optanonConsentCookieName = \'OptanonConsent\';\nvar optanonBoxClosedCookieName = \'OptanonAler
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup =  BeautifulSoup(page.text)

# %%
import re
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
import requests
import numpy as np


Location =[]
Reviews =[]
Property_Name = []
Type_of_Stay=[]
Price = []
Stay_duration_group_size =[]
Taxes_and_Charges =[]
Rating=[]
ReviewType =[]

Locations = ["https://www.booking.com/searchresults.en-gb.html?label=msn-OtA8KVb8PL6q89f9dZV*9g-80814291883323%3Atikwd-80814466535357%3Aloc-90%3Aneo%3Amte%3Alp157592%3Adec%3Aqshttps%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaGyIAQGYATG4ARfIAQzYAQHoAQH4AQKIAgGoAgO4Ar-r478GwAIB0gIkMGI0ODM2NDEtMDQxNC00NGFlLWE5NzctNTE2YjM1NTczOWYw2AIF4AIB&aid=2369666&ss=New+Delhi&ssne=New+Delhi&ssne_untouched=New+Delhi&efdco=1&lang=en-gb&src=searchresults&dest_id=-2106102&dest_type=city&checkin=2025-07-04&checkout=2025-07-05&ltfd=1%3A5%3A7-2025_8-2025%3A1%3A&group_adults=10&no_rooms=5&group_children=0&flex_window=7&nflt=review_score%3D80%3Bclass%3D5%3Breview_score%3D90%3Bprivacy_type%3D3%3Bht_id%3D201%3Bht_id%3D213%3Bclass%3D4%3Bht_id%3D204%3Breview_score%3D70%3Bht_id%3D208",
"https://www.booking.com/searchresults.en-gb.html?label=msn-OtA8KVb8PL6q89f9dZV*9g-80814291883323%3Atikwd-80814466535357%3Aloc-90%3Aneo%3Amte%3Alp157592%3Adec%3Aqshttps%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaGyIAQGYATG4ARfIAQzYAQHoAQH4AQKIAgGoAgO4Ar-r478GwAIB0gIkMGI0ODM2NDEtMDQxNC00NGFlLWE5NzctNTE2YjM1NTczOWYw2AIF4AIB&aid=2369666&ss=New+Delhi&ssne=New+Delhi&ssne_untouched=New+Delhi&lang=en-gb&src=searchresults&dest_id=-2106102&dest_type=city&checkin=2025-07-07&checkout=2025-07-12&ltfd=1%3A5%3A7-2025_8-2025%3A1%3A&group_adults=8&no_rooms=5&group_children=2&age=10&age=2&flex_window=7&nflt=review_score%3D80%3Bclass%3D5%3Breview_score%3D70%3Bht_id%3D208%3Breview_score%3D90%3Bprivacy_type%3D3%3Bht_id%3D201%3Bht_id%3D213%3Bclass%3D4%3Breview_score%3D60",
"https://www.booking.com/searchresults.en-gb.html?label=msn-OtA8KVb8PL6q89f9dZV*9g-80814291883323%3Atikwd-80814466535357%3Aloc-90%3Aneo%3Amte%3Alp157592%3Adec%3Aqshttps%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaGyIAQGYATG4ARfIAQzYAQHoAQH4AQKIAgGoAgO4Ar-r478GwAIB0gIkMGI0ODM2NDEtMDQxNC00NGFlLWE5NzctNTE2YjM1NTczOWYw2AIF4AIB&aid=2369666&ss=New+Delhi&ssne=New+Delhi&ssne_untouched=New+Delhi&lang=en-gb&src=searchresults&dest_id=-2106102&dest_type=city&checkin=2025-07-07&checkout=2025-07-12&ltfd=1%3A5%3A7-2025_8-2025%3A1%3A&group_adults=6&no_rooms=4&group_children=4&age=10&age=2&age=14&age=9&flex_window=7&nflt=review_score%3D80%3Bclass%3D5%3Breview_score%3D70%3Breview_score%3D90%3Breview_score%3D60%3Bprivacy_type%3D3%3Bht_id%3D201%3Bht_id%3D213%3Bclass%3D4%3Bht_id%3D204%3Bfamily_friendly_property%3D1",
"https://www.booking.com/searchresults.en-gb.html?ss=New+Delhi&ssne=New+Delhi&ssne_untouched=New+Delhi&label=msn-OtA8KVb8PL6q89f9dZV*9g-80814291883323%3Atikwd-80814466535357%3Aloc-90%3Aneo%3Amte%3Alp157592%3Adec%3Aqshttps%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaGyIAQGYATG4ARfIAQzYAQHoAQH4AQKIAgGoAgO4Ar-r478GwAIB0gIkMGI0ODM2NDEtMDQxNC00NGFlLWE5NzctNTE2YjM1NTczOWYw2AIF4AIB&aid=2369666&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2106102&dest_type=city&checkin=2025-07-07&checkout=2025-07-12&ltfd=1%3A5%3A7-2025_8-2025%3A1%3A&group_adults=10&no_rooms=3&group_children=0&flex_window=7",
"https://www.booking.com/searchresults.en-gb.html?label=msn-OtA8KVb8PL6q89f9dZV*9g-80814291883323%3Atikwd-80814466535357%3Aloc-90%3Aneo%3Amte%3Alp157592%3Adec%3Aqshttps%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaGyIAQGYATG4ARfIAQzYAQHoAQH4AQKIAgGoAgO4Ar-r478GwAIB0gIkMGI0ODM2NDEtMDQxNC00NGFlLWE5NzctNTE2YjM1NTczOWYw2AIF4AIB&aid=2369666&ss=New+Delhi&ssne=New+Delhi&ssne_untouched=New+Delhi&lang=en-gb&src=searchresults&dest_id=-2106102&dest_type=city&checkin=2025-07-07&checkout=2025-07-12&ltfd=1%3A5%3A7-2025_8-2025%3A1%3A&group_adults=9&no_rooms=3&group_children=1&age=2&flex_window=7&nflt=class%3D5%3Bfamily_friendly_property%3D1%3Breview_score%3D90%3Breview_score%3D60%3Bprivacy_type%3D3%3Bht_id%3D201%3Bht_id%3D213%3Bclass%3D4%3Breview_score%3D80%3Breview_score%3D70%3Bht_id%3D204",
"https://www.booking.com/searchresults.en-gb.html?label=msn-OtA8KVb8PL6q89f9dZV*9g-80814291883323%3Atikwd-80814466535357%3Aloc-90%3Aneo%3Amte%3Alp157592%3Adec%3Aqshttps%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaGyIAQGYATG4ARfIAQzYAQHoAQH4AQKIAgGoAgO4Ar-r478GwAIB0gIkMGI0ODM2NDEtMDQxNC00NGFlLWE5NzctNTE2YjM1NTczOWYw2AIF4AIB&aid=2369666
header = {'Content-Type': 'text/html; charset=UTF-8','User-Agent': 'Chrome/101.0.0.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0','Accept-Encoding': 'gzip, deflate, br'}
    page = requests.get(url,headers =request_header)
    soup= BeautifulSoup(page.text)
    section = soup.find_all('div', class_ = 'c3bdfd4ac2 a0ab5da06c d46ff48a92 f728e61e72 d0acd69e66 c256f1a28a bc2204a477')


    for i in section: 
    
    #Property name
        pro_name = i.find("div",class_="b87c397a13 a3e0b4ffd1")
        if pro_name:
            Property_Name.append(pro_name.text)
        else:
            Property_Name.append(np.nan)
    #------------------------------------------------------------------------------------------------

    #Find the location..
        l= i.find("div",class_="fff1944c52 f4008c3a61")
        l= l.text
        location = re.search(r'^(.*?)Show on map' ,l)
        if location:
            Location.append(location.group(1).strip())
        else:
            Location.append(np.nan)
        
     #------------------------------------------------------------------------------------------------

    #find the type of stay..
        type_of_Stay_tag = i.find("div",class_='e2dbf4738c a60d8c35a0 c812b6be2a f8d2645971')

        if type_of_Stay_tag:
            Type_of_Stay.append(type_of_Stay_tag.get_text(strip=True))
        else:
            Type_of_Stay.append(np.nan)

    # #------------------------------------------------------------------------------------------------


        price_tag = i.find("span", class_="b87c397a13 f2f358d1de ab607752a2")
        if price_tag and price_tag.text:
            clean_discount = re.sub(r'\xa0', '', price_tag.text)
            Price.append(clean_discount)
        else:
            Price.append(np.nan)

        tax = i.find("div",class_="cafac92f4a fcc645b25d")
    # #------------------------------------------------------------------------------------------------


        if tax:
            tax =tax.text
    
            normalized = tax.replace('\xa0', ' ') 
            pattern = r'\+₹\s*([\d,]+)\s+(?:taxes.*|charges.*)'
    
            match = re.search(pattern, normalized)
    
            if match:
                Taxes_and_Charges.append(match.group(1))
            else:
                Taxes_and_Charges.append(np.nan)
        else:
            Taxes_and_Charges.append(np.nan)

        #------------------------------------------------------------------------------------------------

        sd = i.find("div", class_="fff1944c52 fb14de7f14")
        if sd:
            Stay_duration_group_size.append(sd.text)
        else:
            Stay_duration_group_size.append(np.nan)
            
        #------------------------------------------------------------------------------------------------


        r =i.find("div",class_="f6e3a11b0d c465553d73 a81870d302 ac30880487 e95943ce9b afec5495f3 b889bab3b1")

        #r"Scored\s(\d\.\d)"
        if r:
            rat = r.text
            pattern = r"Scored\s(\d\.\d)"  # Correct the pattern format if necessary
            rating = re.search(pattern, rat)
    
            if rating:
                Rating.append(float(rating.group(1)))  # Use .group() to extract the matched text
            else:
                Rating.append(np.nan)
    
        #------------------------------------------------------------------------------------------------
        #reviews :
        # Extract the review type (e.g., Exceptional, very good)
            pattern_review = r'([A-Za-z ]+)\s\d+\sreviews'
            review_match = re.search(pattern_review, rat)
    
            if review_match:
                ReviewType.append(review_match.group(1).strip())
            else:
                ReviewType.append(np.nan)

        else:
            Rating.append(np.nan)
            ReviewType.append(np.nan)

        
        
print(Property_Name)
print(len(Property_Name))


print(Location)
print(len(Location))



print(Type_of_Stay)
print(len(Type_of_Stay))


print(Price)
print(len(Price))



print(Taxes_and_Charges)
print(len(Taxes_and_Charges))



print(Stay_duration_group_size)
print(len(Stay_duration_group_size))



print(Rating)
print(len(Rating))



print(ReviewType)
print(len(ReviewType))
# Out:
# ['Olive Service Apartments Rohini', 'Olive Service Apartments - Greater Kailash', 'Anara Service Apartments - Greater Kailash Part II', 'Homlee-Excellency Large 4BHK-South Delhi- NFC', 'BedChambers Serviced Apartments South Extension', 'Homlee-Green Luxury 3BHK-South DEL-NFC-Lift', 'Olive Serviced Apartments - Defence Colony', 'Ideal 3bhk apartment!Downtown', 'Vista Residences at GK 1 - Air Purifier and Complimentary Breakfast', 'Homlee-Vintage 2BHK-Fort View-Bharat Mandapam-NDLS', 'Homlee-Anupam 3BHK-Lift-Parking-Saket-Max Hospital', 'Homlee-Pentagon 3 BHK luxurious-Lift-Parking-Saket', 'StayVista at The Cityscape with Lawn & Pool', 'Hyatt Delhi Residences', "StayVista's Anantam - Luxury 4BR villa with Huge Swimming Pool in Delhi", 'Fortune Home Service Apartment 3Bhk,J-171 Saket', 'Urban Nest -New 3BHK Apartments', 'Fortune Home Service Apartment 3Bhk,E-28, Saket 2B', 'Safdarjung Enclave', 'Olive Service Apartments Saket', "Hotel Godwin Deluxe -Free Airport Pickup -Traveller's Choi
# ...

# %%
lis =[]
for i in soup.find_all("div",class_='e2dbf4738c a60d8c35a0 c812b6be2a f8d2645971'):
    lis.append(i.text)
lis
# Out:
# ['1×Two-Bedroom ApartmentEntire apartment • 2 bedrooms • 1 living room • 2 bathrooms • 1 kitchen • 111m²2 extra-large double beds',
#  '1×Three-Bedroom ApartmentEntire apartment • 3 bedrooms • 1 living room • 3 bathrooms • 1 kitchen • 149m²3 large double beds',
#  '1×Standard Two-Bedroom ApartmentEntire apartment • 2 bedrooms • 1 living room • 2 bathrooms • 1 kitchen • 98m²2 extra-large double beds',
#  '1×Standard Three-Bedroom ApartmentEntire apartment • 3 bedrooms • 1 living room • 3 bathrooms • 1 kitchen • 139m²3 extra-large double beds',
#  '1×Two-Bedroom ApartmentEntire apartment • 2 bedrooms • 1 living room • 2 bathrooms • 1 kitchen • 93m²2 double bedsFree cancellationNo prepayment needed – pay at the property',
#  '1×ApartmentEntire apartment • 3 bedrooms • 1 living room • 3 bathrooms • 1 kitchen • 111m²5 beds (1 double, 2 extra-large doubles, 2 sofa beds)Free cancellationNo prepayment needed – pay at the property',
# ...

# %%
Price=[]
for i in  soup.find_all("span", class_="b87c397a13 f2f358d1de ab607752a2"):
    if price_tag and price_tag.text:
        clean_discount = re.sub(r'\xa0', '', price_tag.text)
        Price.append(clean_discount)
    else:
        Price.append(np.nan)

Price
# Out:
# ['₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046',
#  '₹83,046']

# %%
data={"Property_name": Property_Name,
    "Location": Location,
    "Rating": Rating,
    "Review" :ReviewType,
    "Type_of_stay": Type_of_Stay,
    "Stay_duration_and_group_size": Stay_duration_group_size,
    "price": Price,
    "Taxes_and_charges_inr": Taxes_and_Charges}
import pandas as pd
df= pd.DataFrame(data)
df
# Out:
#                                           Property_name  \
# 0                       Olive Service Apartments Rohini
# 1            Olive Service Apartments - Greater Kailash
# 2     Anara Service Apartments - Greater Kailash Par...
# 3         Homlee-Excellency Large 4BHK-South Delhi- NFC
# 4       BedChambers Serviced Apartments South Extension
# ...                                                 ...
# 1619                               Northern View Haward
# 1620                        Treebo Greenland, Mall Road
# 1621                   Krishna Hill Stay Near Mall Road
# 1622                       Shimla Hills Apartments 2BHK
# 1623                                 Himalayan Hideaway
#
#                            Location  Rating        Review  \
# 0                 Rohini, New Delhi     9.8   Exceptional
# 1      Greater Kailash 1, New Delhi     9.0        Superb
# 2                         New Delhi     8.3     Very good
# ...
